# %%
import pandas as pd

# %%
d=pd.read_csv(r"C:\Users\lokes\Downloads\e\diamonds.csv")

# %%
d
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
d.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
d.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
d.columns[d.isna().any()]
# Out:
# Index([], dtype='object')

# %%
d.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
d["carat"].unique()
# Out:
# array([0.23, 0.21, 0.29, 0.31, 0.24, 0.26, 0.22, 0.3 , 0.2 , 0.32, 0.33,
#        0.25, 0.35, 0.42, 0.28, 0.38, 0.7 , 0.86, 0.71, 0.78, 0.96, 0.73,
#        0.8 , 0.75, 0.74, 0.81, 0.59, 0.9 , 0.91, 0.61, 0.77, 0.63, 0.76,
#        0.64, 0.72, 0.79, 0.58, 1.17, 0.6 , 0.83, 0.54, 0.98, 0.52, 1.01,
#        0.53, 0.84, 0.51, 1.05, 0.55, 0.87, 1.  , 0.57, 0.82, 1.04, 0.93,
#        1.2 , 0.99, 0.34, 0.43, 0.36, 0.95, 0.89, 1.02, 0.97, 0.56, 0.85,
#        0.92, 1.27, 0.66, 1.12, 0.68, 1.03, 0.62, 1.22, 1.08, 0.88, 0.5 ,
#        1.19, 0.39, 0.65, 1.24, 1.5 , 0.27, 0.41, 1.13, 1.06, 0.69, 0.4 ,
#        1.14, 0.94, 1.29, 1.52, 1.16, 1.21, 1.23, 1.09, 0.67, 1.11, 1.1 ,
#        1.18, 1.15, 1.25, 1.07, 1.28, 1.51, 0.37, 1.31, 1.26, 1.39, 1.44,
#        1.35, 1.3 , 1.32, 1.41, 1.36, 1.45, 1.34, 1.58, 1.54, 1.38, 1.33,
#        1.74, 1.64, 1.47, 1.4 , 1.55, 1.95, 2.  , 1.37, 1.83, 1.62, 1.57,
#        1.69, 2.06, 1.72, 1.66, 2.14, 1.49, 1.46, 2.15, 1.96, 2.22, 1.7 ,
# ...

# %%
d["carat"].value_counts()
# Out:
# carat
# 0.30    2604
# 0.31    2249
# 1.01    2242
# 0.70    1981
# 0.32    1840
#         ...
# 3.02       1
# 3.65       1
# 3.50       1
# 3.22       1
# 3.11       1
# Name: count, Length: 273, dtype: int64

# %%
d=d.drop(["x","y","z"],axis="columns")
d
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326
# 2               3   0.23       Good     E     VS1   56.9   65.0    327
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334
# 4               5   0.31       Good     J     SI2   63.3   58.0    335
# ...           ...    ...        ...   ...     ...    ...    ...    ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757
#
# [53940 rows x 8 columns]

# %%
nd=d.select_dtypes(["float64","int64"])
nd
# Out:
#        Unnamed: 0  carat  depth  table  price
# 0               1   0.23   61.5   55.0    326
# 1               2   0.21   59.8   61.0    326
# 2               3   0.23   56.9   65.0    327
# 3               4   0.29   62.4   58.0    334
# 4               5   0.31   63.3   58.0    335
# ...           ...    ...    ...    ...    ...
# 53935       53936   0.72   60.8   57.0   2757
# 53936       53937   0.72   63.1   55.0   2757
# 53937       53938   0.70   62.8   60.0   2757
# 53938       53939   0.86   61.0   58.0   2757
# 53939       53940   0.75   62.2   55.0   2757
#
# [53940 rows x 5 columns]

# %%
nd.corr()
# Out:
#             Unnamed: 0     carat     depth     table     price
# Unnamed: 0    1.000000 -0.377983 -0.034800 -0.100830 -0.306873
# carat        -0.377983  1.000000  0.028224  0.181618  0.921591
# depth        -0.034800  0.028224  1.000000 -0.295779 -0.010647
# table        -0.100830  0.181618 -0.295779  1.000000  0.127134
# price        -0.306873  0.921591 -0.010647  0.127134  1.000000

# %%
x=nd[["carat","table"]]
y=nd["price"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([-319.434267  , 2266.17130428, 1009.16540114, ..., 9318.43107504,
#        2979.64870042,  933.11140961], shape=(16182,))

# %%
from sklearn.metrics import r2_score

# %%
model.coef_
# Out:
# array([7828.41047886,  -76.05399153])

# %%
model.intercept_
# Out:
# np.float64(2060.7707436159862)

# %%
import numpy as np

# %%
i=[[0.30,71]]
model.predict(i)
# Out:
# C:\Users\lokes\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-990.53951119])

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
fig=plt.figure()
ax=fig.add_subplot(111,projection="3d")
ax.scatter(x["carat"],x["table"],y)

# %%
import numpy as np

# %%
ar=np.linspace(x["carat"].min(),x["carat"].max(),50)
br=np.linspace(x["table"].min(),x["table"].max(),50)
