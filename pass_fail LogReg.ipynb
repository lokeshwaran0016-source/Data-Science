# %%
import pandas as pd

# %%
d=pd.read_csv(r"C:\Users\lokes\Downloads\9\student_exam_performance_dataset.csv")
d
# Out:
#      student_id  gender  age parental_education family_income internet_access  \
# 0        S00001    Male   17        High School        Medium             Yes
# 1        S00002  Female   18        High School           Low             Yes
# 2        S00003    Male   17        High School        Medium              No
# 3        S00004    Male   18           Bachelor        Medium             Yes
# 4        S00005    Male   18           Bachelor        Medium             Yes
# ...         ...     ...  ...                ...           ...             ...
# 9995     S09996  Female   15             Master          High             Yes
# 9996     S09997    Male   15        High School        Medium             Yes
# 9997     S09998  Female   15        High School           Low             Yes
# 9998     S09999  Female   18           Bachelor        Medium             Yes
# 9999     S10000    Male   17        High School           Low             Yes
#
#      study_environment  study_hours_per_day  attendance_rate  sleep_hours  \
# 0                Quiet                 2.98             96.5         6.05
# 1                Quiet                 4.45             95.7         6.96
# 2                Quiet                 3.75             76.0         7.02
# 3                Quiet                 2.03             72.6         6.23
# 4                Quiet                 5.14             87.3         8.54
# ...                ...                  ...              ...          ...
# 9995          Moderate                 3.80             83.1         7.48
# 9996             Quiet                 2.46             68.0         6.76
# 9997          Moderate                 5.08             76.0         6.90
# 9998          Moderate                 1.56             91.0         7.13
# 9999             Noisy                 3.63            100.0         5.42
#
#       ...  online_courses_completed  tutoring  math_score  reading_score  \
# 0     ...                         1       Yes        42.8           62.4
# 1     ...                         0       Yes        77.9           73.5
# 2     ...                         4       Yes        53.5           38.3
# 3     ...                         4        No        28.3           23.5
# 4     ...                         0        No        74.7           54.9
# ...   ...                       ...       ...         ...            ...
# 9995  ...                         1        No        44.2           38.2
# 9996  ...                         3        No        56.8           46.2
# 9997  ...                         2        No        67.4           50.5
# 9998  ...                         1        No        35.4           35.5
# 9999  ...                         0        No        66.7           61.6
#
#      writing_score  science_score  final_exam_score  previous_gpa  pass_fail  \
# 0             54.8           51.8              49.1          2.44       Fail
# 1             64.4           61.6              70.1          2.79       Pass
# 2             36.3           47.1              42.2          1.49       Fail
# 3             32.0           39.0              31.9          1.34       Fail
# 4             73.6           55.5              66.4          2.60       Pass
# ...            ...            ...               ...           ...        ...
# 9995          38.5           39.0              41.9          1.54       Fail
# 9996          50.6           34.9              47.5          1.49       Fail
# 9997          63.7           83.3              64.2          2.38       Pass
# 9998          46.8           47.2              44.3          1.45       Fail
# 9999          60.3           60.4              59.6          2.24       Pass
#
#       grade_category
# 0                  F
# 1                  C
# 2                  F
# 3                  F
# 4                  C
# ...              ...
# 9995               F
# 9996               F
# 9997               D
# 9998               F
# 9999               D
#
# [10000 rows x 23 columns]

# %%
d.head()
# Out:
#   student_id  gender  age parental_education family_income internet_access  \
# 0     S00001    Male   17        High School        Medium             Yes
# 1     S00002  Female   18        High School           Low             Yes
# 2     S00003    Male   17        High School        Medium              No
# 3     S00004    Male   18           Bachelor        Medium             Yes
# 4     S00005    Male   18           Bachelor        Medium             Yes
#
#   study_environment  study_hours_per_day  attendance_rate  sleep_hours  ...  \
# 0             Quiet                 2.98             96.5         6.05  ...
# 1             Quiet                 4.45             95.7         6.96  ...
# 2             Quiet                 3.75             76.0         7.02  ...
# 3             Quiet                 2.03             72.6         6.23  ...
# 4             Quiet                 5.14             87.3         8.54  ...
#
#    online_courses_completed  tutoring  math_score  reading_score  \
# 0                         1       Yes        42.8           62.4
# 1                         0       Yes        77.9           73.5
# 2                         4       Yes        53.5           38.3
# 3                         4        No        28.3           23.5
# 4                         0        No        74.7           54.9
#
#   writing_score  science_score  final_exam_score  previous_gpa  pass_fail  \
# 0          54.8           51.8              49.1          2.44       Fail
# 1          64.4           61.6              70.1          2.79       Pass
# 2          36.3           47.1              42.2          1.49       Fail
# 3          32.0           39.0              31.9          1.34       Fail
# 4          73.6           55.5              66.4          2.60       Pass
#
#    grade_category
# 0               F
# 1               C
# 2               F
# 3               F
# 4               C
#
# [5 rows x 23 columns]

# %%
d.tail()
# Out:
#      student_id  gender  age parental_education family_income internet_access  \
# 9995     S09996  Female   15             Master          High             Yes
# 9996     S09997    Male   15        High School        Medium             Yes
# 9997     S09998  Female   15        High School           Low             Yes
# 9998     S09999  Female   18           Bachelor        Medium             Yes
# 9999     S10000    Male   17        High School           Low             Yes
#
#      study_environment  study_hours_per_day  attendance_rate  sleep_hours  \
# 9995          Moderate                 3.80             83.1         7.48
# 9996             Quiet                 2.46             68.0         6.76
# 9997          Moderate                 5.08             76.0         6.90
# 9998          Moderate                 1.56             91.0         7.13
# 9999             Noisy                 3.63            100.0         5.42
#
#       ...  online_courses_completed  tutoring  math_score  reading_score  \
# 9995  ...                         1        No        44.2           38.2
# 9996  ...                         3        No        56.8           46.2
# 9997  ...                         2        No        67.4           50.5
# 9998  ...                         1        No        35.4           35.5
# 9999  ...                         0        No        66.7           61.6
#
#      writing_score  science_score  final_exam_score  previous_gpa  pass_fail  \
# 9995          38.5           39.0              41.9          1.54       Fail
# 9996          50.6           34.9              47.5          1.49       Fail
# 9997          63.7           83.3              64.2          2.38       Pass
# 9998          46.8           47.2              44.3          1.45       Fail
# 9999          60.3           60.4              59.6          2.24       Pass
#
#       grade_category
# 9995               F
# 9996               F
# 9997               D
# 9998               F
# 9999               D
#
# [5 rows x 23 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   student_id                  10000 non-null  object
#  1   gender                      10000 non-null  object
#  2   age                         10000 non-null  int64
#  3   parental_education          10000 non-null  object
#  4   family_income               10000 non-null  object
#  5   internet_access             10000 non-null  object
#  6   study_environment           10000 non-null  object
#  7   study_hours_per_day         10000 non-null  float64
#  8   attendance_rate             10000 non-null  float64
#  9   sleep_hours                 10000 non-null  float64
#  10  social_media_hours          10000 non-null  float64
#  11  assignment_completion_rate  10000 non-null  float64
#  12  participation_score         10000 non-null  float64
#  13  online_courses_completed    10000 non-null  int64
#  14  tutoring                    10000 non-null  object
#  15  math_score                  10000 non-null  float64
#  16  reading_score               10000 non-null  float64
#  17  writing_score               10000 non-null  float64
#  18  science_score               10000 non-null  float64
#  19  final_exam_score            10000 non-null  float64
#  20  previous_gpa                10000 non-null  float64
#  21  pass_fail                   10000 non-null  object
#  22  grade_category              10000 non-null  object
# dtypes: float64(12), int64(2), object(9)
# memory usage: 1.8+ MB

# %%
d.isnull().any()
# Out:
# student_id                    False
# gender                        False
# age                           False
# parental_education            False
# family_income                 False
# internet_access               False
# study_environment             False
# study_hours_per_day           False
# attendance_rate               False
# sleep_hours                   False
# social_media_hours            False
# assignment_completion_rate    False
# participation_score           False
# online_courses_completed      False
# tutoring                      False
# math_score                    False
# reading_score                 False
# writing_score                 False
# science_score                 False
# final_exam_score              False
# previous_gpa                  False
# pass_fail                     False
# grade_category                False
# dtype: bool

# %%
d.columns[d.isna().sum()]
# Out:
# Index(['student_id', 'student_id', 'student_id', 'student_id', 'student_id',
#        'student_id', 'student_id', 'student_id', 'student_id', 'student_id',
#        'student_id', 'student_id', 'student_id', 'student_id', 'student_id',
#        'student_id', 'student_id', 'student_id', 'student_id', 'student_id',
#        'student_id', 'student_id', 'student_id'],
#       dtype='object')

# %%
nd=d.select_dtypes(include=["int64","float64"])
nd
# Out:
#       age  study_hours_per_day  attendance_rate  sleep_hours  \
# 0      17                 2.98             96.5         6.05
# 1      18                 4.45             95.7         6.96
# 2      17                 3.75             76.0         7.02
# 3      18                 2.03             72.6         6.23
# 4      18                 5.14             87.3         8.54
# ...   ...                  ...              ...          ...
# 9995   15                 3.80             83.1         7.48
# 9996   15                 2.46             68.0         6.76
# 9997   15                 5.08             76.0         6.90
# 9998   18                 1.56             91.0         7.13
# 9999   17                 3.63            100.0         5.42
#
#       social_media_hours  assignment_completion_rate  participation_score  \
# 0                    0.1                        80.5                 68.7
# 1                    2.9                        70.9                 92.6
# 2                    2.4                        77.6                 45.8
# 3                    3.5                        63.5                 72.9
# 4                    2.1                        71.8                 55.7
# ...                  ...                         ...                  ...
# 9995                 2.6                        66.4                 64.1
# 9996                 0.5                       100.0                 79.9
# 9997                 2.8                        97.1                 57.4
# 9998                 3.3                        76.5                 55.0
# 9999                 2.6                        86.9                 77.8
#
#       online_courses_completed  math_score  reading_score  writing_score  \
# 0                            1        42.8           62.4           54.8
# 1                            0        77.9           73.5           64.4
# 2                            4        53.5           38.3           36.3
# 3                            4        28.3           23.5           32.0
# 4                            0        74.7           54.9           73.6
# ...                        ...         ...            ...            ...
# 9995                         1        44.2           38.2           38.5
# 9996                         3        56.8           46.2           50.6
# 9997                         2        67.4           50.5           63.7
# 9998                         1        35.4           35.5           46.8
# 9999                         0        66.7           61.6           60.3
#
#       science_score  final_exam_score  previous_gpa
# 0              51.8              49.1          2.44
# 1              61.6              70.1          2.79
# 2              47.1              42.2          1.49
# 3              39.0              31.9          1.34
# 4              55.5              66.4          2.60
# ...             ...               ...           ...
# 9995           39.0              41.9          1.54
# 9996           34.9              47.5          1.49
# 9997           83.3              64.2          2.38
# 9998           47.2              44.3          1.45
# 9999           60.4              59.6          2.24
#
# [10000 rows x 14 columns]

# %%
x=nd[["participation_score"]]
y = d["pass_fail"]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
xtrain
# Out:
#       participation_score
# 9254                 68.6
# 1561                 92.7
# 1670                 69.8
# 6087                 61.0
# 6669                100.0
# ...                   ...
# 5734                 71.8
# 5191                 45.9
# 5390                 43.7
# 860                  59.5
# 7270                 75.6
#
# [8000 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(xtest,ytest)
# Out:
# LogisticRegression()

# %%
ypred=lr.predict(xtest)
ypred
# Out:
# array(['Fail', 'Fail', 'Pass', ..., 'Fail', 'Fail', 'Fail'],
#       shape=(2000,), dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,ypred)
# Out:
# 0.5475

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(xtrain,ytrain,color="blue")
plt.plot(xtest,ypred,color="green")
plt.show()
