# %%
import pandas as pd

# %%
d=pd.read_csv(r"C:\Users\lokes\Downloads\archive (16)\cluster.csv")
d
# Out:
#         NAME  AGE  HOUR  INCOME
# 0     JAINIL   18    22   10000
# 1       ZAID   60     3   67000
# 2    KRISHNA   55     4   63000
# 3      PALAK   16    20   12000
# 4     ISHITA   63     2   58000
# 5     TWISHA   17    19   13000
# 6     AKSHAT   64     1   62000
# 7    DARSHAN   19    20   12000
# 8     KRISHA   34    14   24000
# 9        RAJ   61     1   65000
# 10     MANOJ   33    14   23000
# 11       DEV   37    16   24000
# 12      FAIZ   38    18   27000
# 13       JAY   23    10   19000
# 14   VIBHAVI   18    21   11000
# 15      RUTU   17    25    9000
# 16    PRACHI   30    17   23000
# 17    SALONI   59     3   60000
# 18  SHRADHHA   18    22    7000
# 19     SWETA   19    21    8000
# 20    ASTUTI   68     2   58000

# %%
d.head()
# Out:
#       NAME  AGE  HOUR  INCOME
# 0   JAINIL   18    22   10000
# 1     ZAID   60     3   67000
# 2  KRISHNA   55     4   63000
# 3    PALAK   16    20   12000
# 4   ISHITA   63     2   58000

# %%
d.tail()
# Out:
#         NAME  AGE  HOUR  INCOME
# 16    PRACHI   30    17   23000
# 17    SALONI   59     3   60000
# 18  SHRADHHA   18    22    7000
# 19     SWETA   19    21    8000
# 20    ASTUTI   68     2   58000

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    21 non-null     object
#  1   AGE     21 non-null     int64
#  2   HOUR    21 non-null     int64
#  3   INCOME  21 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 804.0+ bytes

# %%
d.isna().any()
# Out:
# NAME      False
# AGE       False
# HOUR      False
# INCOME    False
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l= LabelEncoder()
d["NAME"]=l.fit_transform(d["NAME"])
d["NAME"]
# Out:
# 0      6
# 1     20
# 2      9
# 3     11
# 4      5
# 5     18
# 6      0
# 7      2
# 8      8
# 9     13
# 10    10
# 11     3
# 12     4
# 13     7
# 14    19
# 15    14
# 16    12
# 17    15
# 18    16
# 19    17
# 20     1
# Name: NAME, dtype: int64

# %%
x=d[["HOUR","INCOME"]]
x
# Out:
#     HOUR  INCOME
# 0     22   10000
# 1      3   67000
# 2      4   63000
# 3     20   12000
# 4      2   58000
# 5     19   13000
# 6      1   62000
# 7     20   12000
# 8     14   24000
# 9      1   65000
# 10    14   23000
# 11    16   24000
# 12    18   27000
# 13    10   19000
# 14    21   11000
# 15    25    9000
# 16    17   23000
# 17     3   60000
# 18    22    7000
# 19    21    8000
# 20     2   58000

# %%
import scipy.cluster.hierarchy as sch

# %%
import matplotlib.pyplot as plt

# %%
s=sch.dendrogram(sch.linkage(x))
plt.title("dendrogram")
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
